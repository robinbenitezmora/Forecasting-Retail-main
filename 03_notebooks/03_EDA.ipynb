# %% [markdown]
# # EDA

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv
import janitor
import os
from pathlib import Path
import openpyxl
import sqlalchemy as sa

# Desactivar notación científica
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# Cargar variables de entorno
load_dotenv()

print("✅ Librerías importadas correctamente")
# Out:
# ✅ Librerías importadas correctamente

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
cat = pd.read_pickle('../02_datos/03_Entrenamiento/cat_resultado_calidad.pkl')
num = pd.read_pickle('../02_datos/03_Entrenamiento/num_resultado_calidad.pkl')

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %% [markdown]
# No incluímos la variable 'd' ya que va a tener demasiados valores.

# %%
cat.columns.to_list()
# Out:
# ['store_id',
#  'item_id',
#  'd',
#  'year',
#  'month',
#  'wday',
#  'weekday',
#  'event_name_1',
#  'event_type_1']

# %%
incluir = cat.columns.to_list()
del incluir[2]

# %%
def frecuencias_cat(df_cat):
    # Asegúrate de que todas las columnas son de tipo 'str' para evitar problemas de comparación
    df_cat = df_cat.astype(str)
    
    resultado = df_cat.apply(lambda x: x.value_counts(normalize=True)) \
                      .T.stack() \
                      .to_frame().reset_index() \
                      .rename(columns={'level_0': 'Variable', 'level_1': 'Valor', 0: "Frecuencia"}) \
                      .sort_values(by=['Variable', 'Frecuencia'])
    return resultado

# %%
pd.set_option('display.max_rows', None)

frecuencias_cat(cat[incluir])
# Out:
#         Variable                Valor  Frecuencia
# 41  event_name_1         Chanukah End       0.002
# 42  event_name_1            Christmas       0.002
# 43  event_name_1        Cinco De Mayo       0.002
# 48  event_name_1         Father's day       0.002
# 61  event_name_1       OrthodoxEaster       0.002
# 44  event_name_1          ColumbusDay       0.003
# 45  event_name_1               Easter       0.003
# 46  event_name_1          Eid al-Fitr       0.003
# 47  event_name_1            EidAlAdha       0.003
# 49  event_name_1            Halloween       0.003
# 50  event_name_1      IndependenceDay       0.003
# 51  event_name_1             LaborDay       0.003
# 52  event_name_1            LentStart       0.003
# 53  event_name_1            LentWeek2       0.003
# 54  event_name_1  MartinLutherKingDay       0.003
# 55  event_name_1          MemorialDay       0.003
# 56  event_name_1         Mother's day       0.003
# 57  event_name_1         NBAFinalsEnd       0.003
# 58  event_name_1       NBAFinalsStart       0.003
# 59  event_name_1              NewYear       0.003
# 60  event_name_1    OrthodoxChristmas       0.003
# 62  event_name_1           Pesach End       0.003
# 63  event_name_1        PresidentsDay       0.003
# 64  event_name_1            Purim End       0.003
# 65  event_name_1       Ramadan starts       0.003
# 67  event_name_1        StPatricksDay       0.003
# 68  event_name_1            SuperBowl       0.003
# 69  event_name_1         Thanksgiving       0.003
# 70  event_name_1        ValentinesDay       0.003
# 71  event_name_1          VeteransDay       0.003
# 66  event_name_1           Sin evento       0.920
# 76  event_type_1             Sporting       0.008
# 72  event_type_1             Cultural       0.018
# 74  event_type_1            Religious       0.026
# 73  event_type_1             National       0.027
# 75  event_type_1           Sin evento       0.920
# 2        item_id          FOODS_3_090       0.100
# 3        item_id          FOODS_3_120       0.100
# 4        item_id          FOODS_3_202       0.100
# 5        item_id          FOODS_3_252       0.100
# 6        item_id          FOODS_3_288       0.100
# 7        item_id          FOODS_3_329       0.100
# 8        item_id          FOODS_3_555       0.100
# 9        item_id          FOODS_3_586       0.100
# 10       item_id          FOODS_3_587       0.100
# 11       item_id          FOODS_3_714       0.100
# 18         month                   12       0.058
# 19         month                    2       0.079
# 17         month                   11       0.085
# 21         month                    4       0.085
# 23         month                    6       0.085
# 26         month                    9       0.085
# 15         month                    1       0.087
# 16         month                   10       0.087
# 20         month                    3       0.087
# 22         month                    5       0.087
# 24         month                    7       0.087
# 25         month                    8       0.087
# 0       store_id                 CA_3       0.500
# 1       store_id                 CA_4       0.500
# 27          wday                    1       0.143
# 28          wday                    2       0.143
# 29          wday                    3       0.143
# 30          wday                    4       0.143
# 31          wday                    5       0.143
# 32          wday                    6       0.143
# 33          wday                    7       0.143
# 34       weekday               Friday       0.143
# 35       weekday               Monday       0.143
# 36       weekday             Saturday       0.143
# 37       weekday               Sunday       0.143
# 38       weekday             Thursday       0.143
# 39       weekday              Tuesday       0.143
# 40       weekday            Wednesday       0.143
# 14          year                 2015       0.314
# 12          year                 2013       0.343
# 13          year                 2014       0.343

# %%
pd.set_option('display.max_rows', 6)

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat[incluir])

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                count      mean    median    std       min       25%       50%  \
# wm_yr_wk   21280.000 11415.023 11420.000 82.875 11249.000 11335.000 11420.000
# ventas     21280.000    28.875    18.000 38.988     0.000     6.000    18.000
# sell_price 21280.000     2.394     1.580  1.236     1.000     1.500     1.580
#
#                  75%       max
# wm_yr_wk   11506.000 11544.000
# ventas        37.000   763.000
# sell_price     2.980     4.980

# %% [markdown]
# ### Análisis gráfico

# %% [markdown]
# En este caso el análisis gráfico que tiene más sentido es el de ventas y precios por diferentes dimensiones.
#
# Así que primero necesitamos volver a unir los dos dataframes.

# %%
df = pd.concat([cat,num], axis=1)

df.head()
# Out:
#            store_id      item_id      d  year month wday  weekday  \
# date
# 2013-01-01     CA_3  FOODS_3_090  d_704  2013     1    4  Tuesday
# 2013-01-01     CA_3  FOODS_3_120  d_704  2013     1    4  Tuesday
# 2013-01-01     CA_3  FOODS_3_202  d_704  2013     1    4  Tuesday
# 2013-01-01     CA_3  FOODS_3_252  d_704  2013     1    4  Tuesday
# 2013-01-01     CA_3  FOODS_3_288  d_704  2013     1    4  Tuesday
#
#            event_name_1 event_type_1  wm_yr_wk  ventas  sell_price
# date
# 2013-01-01      NewYear     National     11249       0       1.250
# 2013-01-01      NewYear     National     11249      33       1.250
# 2013-01-01      NewYear     National     11249       0       4.980
# 2013-01-01      NewYear     National     11249       0       4.980
# 2013-01-01      NewYear     National     11249      20       4.280

# %% [markdown]
# #### Tendencia global de las ventas

# %%
df.groupby('date').ventas.sum().plot(figsize=(16, 6), rot=45);

# %% [markdown]
# #### Tendencia de las ventas por producto

# %%
df.groupby(['date','item_id']).ventas.sum().unstack().plot(subplots = True,  layout = (5,2), sharex=False, figsize=(20,30));

# %% [markdown]
# #### Tendencia de las ventas por tienda y producto

# %%
df.loc[df.store_id == 'CA_3'].groupby(['date','item_id']).ventas.sum().unstack().plot(subplots = True,  layout = (5,2), sharex=False, figsize=(20,30));

# %%
df.loc[df.store_id == 'CA_4'].groupby(['date','item_id']).ventas.sum().unstack().plot(subplots = True,  layout = (5,2), sharex=False, figsize=(20,30));

# %% [markdown]
# Conclusiones:
#
# * Estructura jerárquica
# * Hay productos nuevos a nivel de tienda
# * Aunque no a nivel general, por lo que podríamos pensar que no son realmente productos nuevos si no demanda intermitente
# * Hay demanda intermitente
#     * No sabemos la causa: falta de demanda, retirada del mercado o rotura de stock
#
# Acciones:
#
# * Modelizar a nivel tienda producto
# * Crear una variable que capture el efecto de la demanda intermitente
# * Utilizar algoritmos basados en árboles y rápidos: lightGBM

# %% [markdown]
# #### Tendencia del precio por producto

# %%
df.groupby(['date','item_id']).sell_price.mean().unstack().plot(subplots = True,  layout = (5,2), sharex=False, figsize=(20,10));

# %% [markdown]
# Conclusiones:
#
# * Las políticas de precio varían mucho por producto
# * Parece que las promociones son frecuentes
# * Sería muy útil disponer de un calendario de promociones

# %% [markdown]
# #### Estacionalidad por producto

# %%
df.groupby(['month','item_id']).ventas.mean().unstack().plot.bar(subplots = True,  layout = (6,2), sharex=False, figsize=(20,30));

# %%
df.groupby(['weekday','item_id']).ventas.mean().unstack().plot.bar(subplots = True,  layout = (6,2), sharex=False, figsize=(20,30));

# %% [markdown]
# #### Estacionalidad por evento

# %%
df.groupby(['event_name_1','item_id']).ventas.mean().unstack().plot.barh(subplots = True,  layout = (6,2), sharex=False, figsize=(20,40));

# %% [markdown]
# #### Estacionalidad por tipo de evento

# %%
df.groupby(['event_type_1','item_id']).ventas.mean().unstack().plot.barh(subplots = True,  layout = (6,2), sharex=False, figsize=(20,40));

# %% [markdown]
# Conclusiones:
#
# * Todas estas variables sí parecen afectar lo cual es buena noticia

# %% [markdown]
# ## GUARDAR DATASETS TRAS EDA

# %%
cat.to_pickle("../02_datos/03_Entrenamiento/cat_resultado_eda.pkl")
num.to_pickle("../02_datos/03_Entrenamiento/num_resultado_eda.pkl")
